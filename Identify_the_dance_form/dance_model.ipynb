# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import os
import random
from shutil import copyfile
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train_dir = '/content/dataset/train/'
test_dir = '/content/dataset/test/'
train_csv = pd.read_csv('/content/dataset/train.csv')
test_csv = pd.read_csv('/content/dataset/test.csv')

# %%
train_csv.head()
# Out:
#      Image         target
# 0   96.jpg       manipuri
# 1  163.jpg  bharatanatyam
# 2  450.jpg         odissi
# 3  219.jpg      kathakali
# 4  455.jpg         odissi

# %%
os.mkdir(r'/content/identify-dance-form')
os.mkdir(r'/content/identify-dance-form/training')
os.mkdir(r'/content/identify-dance-form/testing')
os.mkdir(r'/content/identify-dance-form/source')
os.mkdir(r'/content/identify-dance-form/training/manipuri')
os.mkdir(r'/content/identify-dance-form/testing/manipuri')
os.mkdir(r'/content/identify-dance-form/source/manipuri')
os.mkdir(r'/content/identify-dance-form/training/bharatanatyam')
os.mkdir(r'/content/identify-dance-form/testing/bharatanatyam')
os.mkdir(r'/content/identify-dance-form/source/bharatanatyam')
os.mkdir(r'/content/identify-dance-form/training/odissi')
os.mkdir(r'/content/identify-dance-form/testing/odissi')
os.mkdir(r'/content/identify-dance-form/source/odissi')
os.mkdir(r'/content/identify-dance-form/training/kathakali')
os.mkdir(r'/content/identify-dance-form/testing/kathakali')
os.mkdir(r'/content/identify-dance-form/source/kathakali')
os.mkdir(r'/content/identify-dance-form/training/kathak')
os.mkdir(r'/content/identify-dance-form/testing/kathak')
os.mkdir(r'/content/identify-dance-form/source/kathak')
os.mkdir(r'/content/identify-dance-form/training/sattriya')
os.mkdir(r'/content/identify-dance-form/testing/sattriya')
os.mkdir(r'/content/identify-dance-form/source/sattriya')
os.mkdir(r'/content/identify-dance-form/training/kuchipudi')
os.mkdir(r'/content/identify-dance-form/testing/kuchipudi')
os.mkdir(r'/content/identify-dance-form/source/kuchipudi')
os.mkdir(r'/content/identify-dance-form/training/mohiniyattam')
os.mkdir(r'/content/identify-dance-form/testing/mohiniyattam')
os.mkdir(r'/content/identify-dance-form/source/mohiniyattam')
os.mkdir('/content/identify-dance-form/tests')
os.mkdir('/content/identify-dance-form/tests/unknown')

# %%
files = []
for  r, d, f in os.walk(train_dir):
    for file in f:
        if '.jpg' in file:
            files.append(file)

# %%
for x in files:
    if (train_csv[train_csv['Image'] == x]['target'] == 'odissi').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/odissi/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'manipuri').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/manipuri/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'bharatanatyam').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/bharatanatyam/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'kathakali').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/kathakali/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'kathak').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/kathak/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'sattriya').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/sattriya/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'kuchipudi').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/kuchipudi/',x)
        copyfile(train_temp, final_train)
    elif (train_csv[train_csv['Image'] == x]['target'] == 'mohiniyattam').bool():
        train_temp = os.path.join(train_dir,x)
        final_train = os.path.join('/content/identify-dance-form/source/mohiniyattam/',x)
        copyfile(train_temp, final_train)

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    shuffle=random.sample(os.listdir(SOURCE),len(os.listdir(SOURCE)))
    train_data_length=int(len(os.listdir(SOURCE))*SPLIT_SIZE)
    test_data_length=int(len(os.listdir(SOURCE))-train_data_length)
    train_data=shuffle[0:train_data_length]
    test_data=shuffle[-test_data_length:]
    for x in train_data:
        train_temp=os.path.join(SOURCE,x)
        final_train=os.path.join(TRAINING,x)
        copyfile(train_temp,final_train)
    for x in test_data:
        test_temp=os.path.join(SOURCE,x)
        final_test=os.path.join(TESTING,x)
        copyfile(test_temp,final_test)

# %%
bhatanatyam_source_dir = '/content/identify-dance-form/source/bharatanatyam/'
bhatanatyam_training_dir = '/content/identify-dance-form/training/bharatanatyam/'
bhatanatyam_testing_dir = '/content/identify-dance-form/testing/bharatanatyam/'

kathak_source_dir = '/content/identify-dance-form/source/kathak/'
kathak_training_dir = '/content/identify-dance-form/training/kathak/'
kathak_testing_dir = '/content/identify-dance-form/testing/kathak/'

kathakali_source_dir = '/content/identify-dance-form/source/kathakali/'
kathakali_training_dir = '/content/identify-dance-form/training/kathakali/'
kathakali_testing_dir = '/content/identify-dance-form/testing/kathakali/'

kuchipudi_source_dir = '/content/identify-dance-form/source/kuchipudi/'
kuchipudi_training_dir = '/content/identify-dance-form/training/kuchipudi/'
kuchipudi_testing_dir = '/content/identify-dance-form/testing/kuchipudi/'

manipuri_source_dir = '/content/identify-dance-form/source/manipuri/'
manipuri_training_dir = '/content/identify-dance-form/training/manipuri/'
manipuri_testing_dir = '/content/identify-dance-form/testing/manipuri/'

mohiniyattam_source_dir = '/content/identify-dance-form/source/mohiniyattam/'
mohiniyattam_training_dir = '/content/identify-dance-form/training/mohiniyattam/'
mohiniyattam_testing_dir = '/content/identify-dance-form/testing/mohiniyattam/'

odissi_source_dir = '/content/identify-dance-form/source/odissi/'
odissi_training_dir = '/content/identify-dance-form/training/odissi/'
odissi_testing_dir = '/content/identify-dance-form/testing/odissi/'

sattriya_source_dir = '/content/identify-dance-form/source/sattriya/'
sattriya_training_dir = '/content/identify-dance-form/training/sattriya/'
sattriya_testing_dir = '/content/identify-dance-form/testing/sattriya/'

# %%
split_size = 0.85
split_data(bhatanatyam_source_dir, bhatanatyam_training_dir, bhatanatyam_testing_dir, split_size)
split_data(sattriya_source_dir, sattriya_training_dir, sattriya_testing_dir, split_size)
split_data(odissi_source_dir, odissi_training_dir, odissi_testing_dir, split_size)
split_data(mohiniyattam_source_dir, mohiniyattam_training_dir, mohiniyattam_testing_dir, split_size)
split_data(manipuri_source_dir, manipuri_training_dir, manipuri_testing_dir, split_size)
split_data(kuchipudi_source_dir, kuchipudi_training_dir, kuchipudi_testing_dir, split_size)
split_data(kathakali_source_dir, kathakali_training_dir, kathakali_testing_dir, split_size)
split_data(kathak_source_dir, kathak_training_dir, kathak_testing_dir, split_size)

# %%
from tensorflow.keras.applications.xception import Xception

base_model = Xception(include_top = False,
                            input_shape = (224,224,3),
                            weights = 'imagenet')

base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_7[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
base_model.trainable = True

print(len(base_model.layers))

fine_tune_at = 127
# Out:
# 132

# %%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %%
last_output = base_model.output

# %%
x = tf.keras.layers.Flatten()(last_output)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(8, activation = 'softmax')(x)

# %%
model = tf.keras.Model(base_model.input, x)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_7[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
TRAINING_DIR = "/content/identify-dance-form/training"
train_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.1,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                   target_size=(224,224),
                                                   color_mode = 'rgb',
                                                   batch_size=32,
                                                   class_mode='categorical')

VALIDATION_DIR = "/content/identify-dance-form/testing"
validation_datagen = ImageDataGenerator(rescale=1./255)


validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                   target_size=(224,224),
                                                   color_mode = 'rgb',
                                                   batch_size=32,
                                                   class_mode='categorical')
# Out:
# Found 305 images belonging to 8 classes.
# Found 59 images belonging to 8 classes.

# %%
model.compile(tf.keras.optimizers.RMSprop(lr = 0.001), loss='categorical_crossentropy', metrics=['acc'])

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.000000001)

# %%
history = model.fit_generator(train_generator,
                              epochs=40,
                              verbose=1,
                              validation_data=validation_generator,
                             callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/40
# 10/10 [==============================] - 90s 9s/step - loss: 59.5921 - acc: 0.2361 - val_loss: 16.4428 - val_acc: 0.4237 - lr: 0.0010
# Epoch 2/40
# 10/10 [==============================] - 89s 9s/step - loss: 8.5140 - acc: 0.4689 - val_loss: 11.9089 - val_acc: 0.4746 - lr: 0.0010
# Epoch 3/40
# 10/10 [==============================] - 89s 9s/step - loss: 4.1915 - acc: 0.5869 - val_loss: 6.0390 - val_acc: 0.5763 - lr: 0.0010
# Epoch 4/40
# 10/10 [==============================] - 89s 9s/step - loss: 1.8637 - acc: 0.7279 - val_loss: 4.7668 - val_acc: 0.5932 - lr: 0.0010
# Epoch 5/40
# 10/10 [==============================] - 89s 9s/step - loss: 2.2908 - acc: 0.6918 - val_loss: 4.2735 - val_acc: 0.6271 - lr: 0.0010
# Epoch 6/40
# 10/10 [==============================] - 89s 9s/step - loss: 1.1631 - acc: 0.7410 - val_loss: 5.7440 - val_acc: 0.5932 - lr: 0.0010
# Epoch 7/40
# ...

# %%
plt.figure(figsize=(15,7))
ax1 = plt.subplot(1,2,1)
ax1.plot(history.history['loss'], color='b', label='Training Loss') 
ax1.plot(history.history['val_loss'], color='r', label = 'Validation Loss',axes=ax1)
legend = ax1.legend(loc='best', shadow=True)
ax2 = plt.subplot(1,2,2)
ax2.plot(history.history['acc'], color='b', label='Training Accuracy') 
ax2.plot(history.history['val_acc'], color='r', label = 'Validation Accuracy')
legend = ax2.legend(loc='best', shadow=True)

# %%
fil = []
for  r, d, f in os.walk(test_dir):
    for file in f:
        if '.jpg' in file:
            fil.append(file)

# %%
for x in fil:
    train_temp = os.path.join(test_dir,x)
    final_train = os.path.join('/content/identify-dance-form/tests/unknown',x)
    copyfile(train_temp, final_train)

# %%
tests_dir = '/content/identify-dance-form/tests'
test_datagen = ImageDataGenerator(rescale = 1./255)
test_generator = test_datagen.flow_from_directory(tests_dir,
                                                  target_size = (224,224),
                                                  color_mode = 'rgb',
                                                  batch_size=32,
                                                  class_mode=None,
                                                  shuffle=False,
                                                  seed=42)
# Out:
# Found 156 images belonging to 1 classes.

# %%
img_list = []
for x in test_generator.filenames:
    x = x.split('/')[1]
    img_list.append(x)

# %%
predictions = model.predict_generator(test_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-71-9068eb02ed61>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
predicted_clases = np.argmax(predictions,axis=-1)
train_generator.class_indices
# Out:
# {'bharatanatyam': 0,
#  'kathak': 1,
#  'kathakali': 2,
#  'kuchipudi': 3,
#  'manipuri': 4,
#  'mohiniyattam': 5,
#  'odissi': 6,
#  'sattriya': 7}

# %%
data = {'Image': img_list, 'target': predicted_clases}
df = pd.DataFrame(data)
df['target']= df['target'].map({0: 'bharatanatyam',
                                1: 'kathak',
                                2: 'kathakali',
                                3: 'kuchipudi',
                                4: 'manipuri',
                                5: 'mohiniyattam',
                                6: 'odissi',
                                7: 'sattriya'})

df.head()
# Out:
#      Image    target
# 0  108.jpg  manipuri
# 1   11.jpg    kathak
# 2  110.jpg  manipuri
# 3  112.jpg    odissi
# 4  114.jpg    odissi

# %%
df.to_csv('submission.csv', index=False)
